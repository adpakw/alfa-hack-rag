# %% [markdown]
# # Baseline
#
# 1. Получение данных
# 2. Обрезка текста до максимальной длины
# 3. Вычисление эмбеддингов текстов
# 4. Вычисление меры близости
# 5. Выбор топ 5 текстов подходящих для ответа на вопрос
#
# - Препроцессинг: **Обрезка текста до максимальной длины**
# - Модель для извлечения эмбеддингов: **ai-forever/ru-en-RoSBERTa**
# - Мера близости: **косинусное расстояние**

# %% [markdown]
# # Import

# %%
import os

while os.getcwd().split("/")[-1] != "alfa-hack-rag":
    os.chdir(os.path.abspath(os.path.join(os.getcwd(), "..")))

# %%
import numpy as np
import pandas as pd
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
from tqdm import tqdm

# %% [markdown]
# # Data

# %%
df_websites = pd.read_csv("data/websites_updated.csv")
df_questions = pd.read_csv("data/questions_clean.csv")
df_sample = pd.read_csv("data/sample_submission.csv")

# %%
df_websites
# Out:
#       web_id                                                url  kind  \
# 0          1                               https://alfabank.ru/  html
# 1          2                        https://alfabank.ru/a-club/  html
# 2          3               https://alfabank.ru/a-club/ultimate/  html
# 3          4                 https://alfabank.ru/actions/rules/  html
# 4          5                    https://alfabank.ru/alfafuture/  html
# ...      ...                                                ...   ...
# 1933    1934  https://alfabank.ru/help/t/retail/alfaforbusin...  html
# 1934    1935  https://alfabank.ru/help/articles/investments/...  html
# 1935    1936  https://alfabank.ru/make-money/investments/hel...  html
# 1936    1937                https://alfabank.ru/everyday/smart/  html
# 1937    1938           https://job.alfabank.ru/vacancies/moskva   NaN
#
#                                                   title  \
# 0     Альфа-Банк - кредитные и дебетовые карты, кред...
# 1                         А-Клуб. Деньги имеют значение
# 2                         А-Клуб. Деньги имеют значение
# 3                                      Скидки по картам
# 4     Альфа‑Будущее: Платформа для развития студенто...
# ...                                                 ...
# 1933  Как вернуть деньги покупателю и как рассчитыва...
# 1934  Как вывести деньги с брокерского счёта — Альфа...
# 1935      Пополнение и вывод средств — Альфа-Инвестиции
# 1936                 Альфа-Смарт — подписка Альфа-Банка
# 1937                                                NaN
#
#                                                    text
# 0     Рассчитайте выгоду\nРасчёт калькулятора предва...
# 1     Брокерские услуги\nОткрытие брокерского счёта ...
# 2     Хотите получить больше информации?\nПозвоните ...
# 3     Правила проведения Акции «Альфа Пятница. Бараб...
# 4     Образование\nМагистратуры\nМагистратура ВШЭ\nМ...
# ...                                                 ...
# 1933  Возврат денег покупателю можно оформить через ...
# 1934  Вывести деньги с брокерского счёта можно на ка...
# 1935  Вывести деньги с брокерского счёта можно на сл...
# 1936  Альфа-Смарт — семейная подписка, запущенная в ...
# 1937                                                NaN
#
# [1938 rows x 5 columns]

# %% [markdown]
# # Preproccesing

# %%
def shorten(text, max_length=2048):
    return text[:max_length]

# %% [markdown]
# # Compute sentence embeddings

# %%
def embed_text(df, model_name, target_col, batch_size=32):
    model = SentenceTransformer(model_name)
    
    texts = df[target_col].fillna('').astype(str).apply(shorten).tolist()

    result = []
    for i in tqdm(range(0, len(texts), batch_size), desc="Encoding"):
        batch = texts[i:i+batch_size]
        emb = model.encode(batch, 
                          convert_to_numpy=True, 
                          normalize_embeddings=True)
        result.append(emb)
    
    result = np.vstack(result)
    
    embedding_columns = [f'embedding_{i}' for i in range(result.shape[1])]
    df_with_embeddings = df.copy()
    df_with_embeddings[embedding_columns] = result
    
    return df_with_embeddings

# %%
sites = embed_text(df_websites, 'ai-forever/ru-en-RoSBERTa', 'text')
sites
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/241 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]

# %%
questions = embed_text(df_questions, 'ai-forever/ru-en-RoSBERTa', 'query')
questions
# Out:
# Encoding: 100%|██████████| 219/219 [01:06<00:00,  3.30it/s]
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# ...
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
# /tmp/ipykernel_24831/3588682663.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_with_embeddings[embedding_columns] = result
#       q_id                                              query  embedding_0  \
# 0        1                                        Номер счета    -0.009606
# 1        2                              Где узнать бик и счёт    -0.027913
# 2        3  Мне не приходят коды для подтверждения данной ...     0.006544
# 3        4  Оформила рассрочку ,но уведомлений никаких не ...    -0.034723
# 4        5  Здравствуйте, когда смогу пользоваться кредитн...    -0.033890
# ...    ...                                                ...          ...
# 6972  6973  Здравствуйте, оплатил вчера ЖКХ а кэшбек не на...    -0.015995
# 6973  6974  Здравствуйте,  можно ли заказать реквизиты бан...    -0.008595
# 6974  6975  Здравствуйте, подскажите пожалуйста где я могу...    -0.019299
# 6975  6976                  Реквизиты для оплаты номера карты    -0.003291
# 6976  6977  Можно ли отключить автопополнение брокерского ...    -0.006110
#
#       embedding_1  embedding_2  embedding_3  embedding_4  embedding_5  \
# 0        0.022116    -0.015717     0.021197    -0.000418    -0.001497
# 1        0.001696     0.002724     0.016252     0.016995     0.007613
# 2       -0.023364    -0.026909    -0.030549     0.014789     0.047667
# 3        0.006657    -0.009752    -0.003755     0.000713     0.003430
# 4        0.011957     0.014870     0.008979    -0.042151     0.018168
# ...           ...          ...          ...          ...          ...
# 6972    -0.012645    -0.026982    -0.007115    -0.036015     0.017858
# 6973     0.012027     0.004211     0.002909    -0.004248    -0.028359
# 6974     0.014888    -0.001857     0.002746    -0.012152     0.016654
# 6975    -0.026090     0.004332     0.013851     0.025512    -0.003967
# 6976    -0.027505     0.007682     0.042273     0.010530     0.001983
#
#       embedding_6  embedding_7  ...  embedding_1526  embedding_1527  \
# 0        0.010700     0.056437  ...       -0.005985       -0.014645
# 1        0.024111     0.058602  ...       -0.010818       -0.035081
# 2        0.001782     0.036237  ...       -0.027244       -0.005069
# 3        0.004350     0.034954  ...       -0.043031       -0.009955
# 4       -0.013802    -0.011115  ...       -0.025627       -0.011822
# ...           ...          ...  ...             ...             ...
# 6972     0.013707     0.024371  ...       -0.039250       -0.047196
# 6973    -0.025351     0.001484  ...       -0.032040        0.006886
# 6974     0.005697     0.072246  ...       -0.025471       -0.020309
# 6975     0.009249     0.062804  ...        0.032208       -0.048678
# 6976    -0.011634     0.033060  ...        0.017485       -0.040441
#
#       embedding_1528  embedding_1529  embedding_1530  embedding_1531  \
# 0           0.036027       -0.043435       -0.023419        0.034221
# 1           0.019946       -0.025626       -0.020042        0.028988
# 2          -0.010190       -0.006286        0.028107        0.027441
# 3          -0.024805       -0.045295        0.008682       -0.010122
# 4           0.011554       -0.019789        0.012919        0.035903
# ...              ...             ...             ...             ...
# 6972       -0.018864       -0.034330       -0.008868       -0.004614
# 6973       -0.004590       -0.013969       -0.009959       -0.011138
# 6974        0.008900       -0.071408       -0.008846       -0.000405
# 6975        0.021592       -0.038068       -0.003432       -0.008183
# 6976        0.004552        0.016633       -0.018251        0.031241
#
#       embedding_1532  embedding_1533  embedding_1534  embedding_1535
# 0          -0.018146       -0.052293       -0.019528        0.016299
# 1           0.014868       -0.025700       -0.056265        0.016393
# 2           0.017797        0.018892        0.012521        0.020908
# 3          -0.000699        0.003615        0.028302        0.014569
# 4           0.035126        0.031286        0.017035        0.066977
# ...              ...             ...             ...             ...
# 6972        0.031712       -0.009220       -0.001613       -0.017158
# 6973        0.023577       -0.014513       -0.008708        0.071997
# 6974        0.027210        0.000220        0.018858        0.022620
# 6975        0.006754       -0.053036        0.005197        0.022635
# 6976        0.003854        0.001931        0.023976        0.014721
#
# [6977 rows x 1538 columns]

# %% [markdown]
# # Similarity

# %%
def cosine_sim(df_sites, df_question):
    cols_sites = [col for col in df_sites.columns if col.startswith('embedding_')]
    cols_question = [col for col in df_question.columns if col.startswith('embedding_')]

    site_embeddings = df_sites[cols_sites].values
    question_embeddings = df_question[cols_question].values

    cosine_sim_matrix = cosine_similarity(question_embeddings, site_embeddings)

    results = []
    
    for i, (q_idx, question_row) in enumerate(tqdm(df_question.iterrows(), total=len(df_question), desc="Processing")):
        for j, (s_idx, site_row) in enumerate(df_sites.iterrows()):
            cosine_sim = cosine_sim_matrix[i, j]
            
            results.append({
                'q_id': question_row['q_id'],
                'web_id': site_row['web_id'],
                'query': question_row['query'],
                'site_text': site_row['text'],
                'cosine_similarity': cosine_sim
            })
    
    # Создаем финальный датафрейм
    cosine_df = pd.DataFrame(results)

    return cosine_df

# %%
cosine_df = cosine_sim(sites, questions)
# Out:
# Processing: 100%|██████████| 6977/6977 [08:19<00:00, 13.96it/s]

# %%
cosine_df
# Out:
#           q_id  web_id                                              query  \
# 0            1       1                                        Номер счета
# 1            1       2                                        Номер счета
# 2            1       3                                        Номер счета
# 3            1       4                                        Номер счета
# 4            1       5                                        Номер счета
# ...        ...     ...                                                ...
# 13521421  6977    1934  Можно ли отключить автопополнение брокерского ...
# 13521422  6977    1935  Можно ли отключить автопополнение брокерского ...
# 13521423  6977    1936  Можно ли отключить автопополнение брокерского ...
# 13521424  6977    1937  Можно ли отключить автопополнение брокерского ...
# 13521425  6977    1938  Можно ли отключить автопополнение брокерского ...
#
#                                                   site_text  cosine_similarity
# 0         Рассчитайте выгоду\nРасчёт калькулятора предва...           0.167539
# 1         Брокерские услуги\nОткрытие брокерского счёта ...           0.245613
# 2         Хотите получить больше информации?\nПозвоните ...           0.149656
# 3         Правила проведения Акции «Альфа Пятница. Бараб...           0.108419
# 4         Образование\nМагистратуры\nМагистратура ВШЭ\nМ...           0.139368
# ...                                                     ...                ...
# 13521421  Возврат денег покупателю можно оформить через ...           0.186377
# 13521422  Вывести деньги с брокерского счёта можно на ка...           0.417687
# 13521423  Вывести деньги с брокерского счёта можно на сл...           0.373985
# 13521424  Альфа-Смарт — семейная подписка, запущенная в ...           0.316801
# 13521425                                                NaN           0.154373
#
# [13521426 rows x 5 columns]

# %%
top5_df = cosine_df.groupby('q_id').apply(
    lambda x: x.nlargest(5, 'cosine_similarity')
).reset_index(drop=True)
# Out:
# /tmp/ipykernel_24831/1209601596.py:1: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   top5_df = cosine_df.groupby('q_id').apply(

# %%
top5_df
# Out:
#        q_id  web_id                                              query  \
# 0         1    1157                                        Номер счета
# 1         1     372                                        Номер счета
# 2         1    1896                                        Номер счета
# 3         1     593                                        Номер счета
# 4         1    1098                                        Номер счета
# ...     ...     ...                                                ...
# 34880  6977    1304  Можно ли отключить автопополнение брокерского ...
# 34881  6977     438  Можно ли отключить автопополнение брокерского ...
# 34882  6977     432  Можно ли отключить автопополнение брокерского ...
# 34883  6977    1935  Можно ли отключить автопополнение брокерского ...
# 34884  6977    1107  Можно ли отключить автопополнение брокерского ...
#
#                                                site_text  cosine_similarity
# 0      Альфа-Банк\nПолезное о продуктах\nЧтобы получа...           0.422728
# 1      Альфа-Банк\nПолезное о продуктах\nВ статье раз...           0.422688
# 2      Номер карты можно посмотреть на самой карте, в...           0.422145
# 3                    31.01.2025\nПодробнее: «Альфа‑Счёт»           0.407634
# 4      Альфа-Банк\nПолезное о продуктах\nIBAN (Intern...           0.407426
# ...                                                  ...                ...
# 34880  Самый лёгкий способ начать копить\nАвтоматичес...           0.456107
# 34881  Как открыть брокерский счёт? Сколько времени н...           0.431020
# 34882  Откройте брокерский счёт в Альфа‑Банке\nСчёт б...           0.419225
# 34883  Вывести деньги с брокерского счёта можно на ка...           0.417687
# 34884  Альфа-Банк\nПолезное о продуктах\nБрокерские с...           0.402126
#
# [34885 rows x 5 columns]

# %%
web_list_df = top5_df.groupby('q_id')['web_id'].apply(
    lambda x: "[" + ", ".join(map(str, x.tolist())) + "]"
).reset_index()
web_list_df.columns = ['q_id', 'web_list']

# %%
from datetime import datetime

web_list_df.to_csv(f'ranking_results/submit{datetime.now()}.csv', index=False)
